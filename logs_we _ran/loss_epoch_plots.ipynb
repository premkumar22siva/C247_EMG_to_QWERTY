# %%
# Function to clean data
def clean(list):
    for i in np.arange(1,50):
        if (list[i] >= 100):
            list[i] = list[i-1]

    return list

import numpy as np
import matplotlib.pyplot as plt

# Example epoch values
epochs = np.arange(1, 51)  # 50 epochs (adjust as needed)


# Baseline Data
loss_baseline = clean([
    3.43, 3.43, 3.25, 3.21, 3.19, 3.03, 2.99, 2.9, 2.93, 2.69,
    2.51, 2.33, 2.29, 2.05, 1.92, 1.84, 1.82, 1.63, 1.47, 1.37,
    1.23, 1.26, 1.15, 1.12, 1.08, 1.05, 0.975, 0.995, 0.952, 0.874,
    0.93, 0.82, 0.834, 0.805, 0.778, 0.742, 0.736, 0.709, 0.72,
    0.675, 0.629, 0.661, 0.6, 0.614, 0.577, 0.572, 0.583, 0.578,
    0.569, 0.556
])
print(np.size(loss_baseline))
val_CER_baseline = clean([
    100, 100, 100, 100, 100, 100, 100, 100, 100, 99.86708,
    95.83518, 89.25565, 83.60656, 79.06513, 71.04564, 69.16261, 67.10235, 64.06734, 49.88923, 39.41072,
    37.39477, 36.37572, 30.92601, 29.46389, 100, 28.31192, 27.51440, 26.07443, 25.38768, 100,
    25.23261, 24.54586, 100, 23.26097, 100, 100, 100, 21.33363, 100,
    21.28932, 100, 100, 100, 21.24502, 20.97918, 100, 100, 100, 20.82410,
    20.69118
])
print(np.size(val_CER_baseline))

# 4 LSTM + 4 Conv
loss_4LSTM4CNN = clean([
    3.4, 3.4, 3.41, 3.51, 3.28, 3.23, 3.08, 2.97, 2.87, 2.73,
    2.51, 2.23, 2.04, 1.92, 1.8, 1.72, 1.54, 1.38, 1.34, 1.22,
    1.26, 1.17, 1.08, 0.999, 0.986, 0.999, 0.964, 0.908, 0.909, 0.837,
    0.786, 0.8, 0.771, 0.75, 0.687, 0.67, 0.663, 0.595, 0.575, 0.563,
    0.536, 0.516, 0.492, 0.487, 0.46, 0.474, 0.45, 0.458, 0.444, 0.441
])
print(np.size(loss_4LSTM4CNN))
val_CER_4LSTM4CNN = clean([
    100.02216, 100, 100, 100, 100, 100, 100, 100, 100, 100,
    97.36375, 88.45813, 86.90740, 68.12140, 51.68365, 44.57244,
    40.47408, 37.32831, 35.97696, 34.22685, 100, 100, 29.95126,
    26.47319, 100, 100, 25.94151, 24.03633, 100, 100, 21.73239,
    100, 21.68808, 100, 20.11520, 100, 100, 19.67213, 18.69739,
    18.56447, 100, 18.27647, 17.96633, 100, 100, 17.78910,
    17.76695, 17.65618, 17.32388, 100
])
print(np.size(val_CER_4LSTM4CNN))

# 4 LSTM + 2 Conv
loss_4LSTM2CNN = clean([
    3.44, 3.44, 3.36, 3.25, 3.15, 3.02, 2.97, 2.84, 2.63, 2.37,
    2.12, 1.95, 1.77, 1.62, 1.55, 1.52, 1.41, 1.39, 1.31, 1.32,
    1.25, 1.25, 1.18, 1.21, 1.17, 1.15, 1.12, 1.08, 1.04, 0.995,
    0.977, 0.978, 0.922, 0.871, 0.884, 0.854, 0.845, 0.809, 0.788,
    0.778, 0.689, 0.654, 0.612, 0.57, 0.579, 0.555, 0.536, 0.532,
    0.511, 0.525
]) 
print(np.size(loss_4LSTM2CNN))
val_CER_4LSTM2CNN = clean([
    100, 100, 100, 100, 100, 100, 100, 100, 100, 94.10722,
    81.43553, 60.45636, 51.06336, 48.47142, 100, 44.99335, 42.93310,
    100, 38.43598, 100, 37.21754, 100, 34.89145, 100, 100, 100,
    33.16349, 100, 31.23615, 30.63802, 100, 100, 100, 30.37218,
    29.15374, 100, 28.31192, 27.29287, 100, 100, 25.29907,
    22.70713, 21.24502, 21.17856, 20.35888, 20.00443,
    19.87151, 19.73859, 100, 19.73859
])
print(np.size(val_CER_4LSTM2CNN))


# 4 LSTM
loss_4LSTM = clean([
    3.81, 3.81, 3.43, 3.33, 3.31, 3.22, 3.2, 3.18, 3.13, 3.1,
    2.94, 2.95, 2.63, 2.41, 2.23, 1.91, 1.72, 1.92, 1.47, 1.34,
    1.5, 1.26, 1.23, 1.21, 1.16, 1.07, 1.03, 1.03, 0.97, 0.951,
    0.909, 0.904, 0.89, 0.833, 0.799, 0.779, 0.756, 0.738,
    0.688, 0.713, 0.676, 0.659, 0.667, 0.661, 0.642,
    0.618, 0.603, 0.606, 0.624, 0.624
])
print(np.size(loss_4LSTM))
val_CER_4LSTM = clean([
    100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
    100, 100, 100, 100, 91.22729, 59.79176,
    47.69606, 100, 41.53744, 39.05627, 100, 37.61631, 34.49269,
    100, 32.89765, 30.66017, 100, 30.17280, 28.53345, 27.42579,
    26.03013, 100, 100, 24.41294, 24.23571, 23.23881, 100, 100,
    21.71024, 100, 21.20071, 21.08994, 20.97918, 20.22596,
    100, 20.20381, 20.11520, 19.93797, 19.89366, 19.51706
])
print(np.size(val_CER_4LSTM))

# 4 CNN + 4 LSTM
loss_4CNN_4LSTM = clean([3.61, 3.61, 3.43, 3.46, 3.33, 3.29, 3.21, 3.08, 2.99, 3.1, 
2.94, 2.73, 2.49, 2.22, 2.08, 2.03, 1.64, 1.57, 1.43, 1.27,
1.21, 1.1, 1.2, 1.06, 1.02, 1.1, 0.989, 0.915, 0.845, 0.885,
0.93, 0.82, 0.759, 0.752, 0.69, 0.679, 0.634, 0.612, 0.606,
0.602, 0.562, 0.549, 0.516, 0.525, 0.472, 0.494, 0.475,
0.478, 0.465, 0.468])
print(np.size(loss_4CNN_4LSTM))
val_CER_4CNN_4LSTM = clean([100, 100.00000, 100.00000, 100.00000, 100.00000, 
100.00000, 100.00000, 100.00000, 100.00000, 100.00000, 
100.00000, 100.00000, 100.00000, 98.18343, 90.38547, 
86.30926, 59.19362, 100.00000, 36.70802, 35.06868, 
34.29331, 28.99867, 100.00000, 28.86575, 27.82454,
27.31502, 25.69783, 24.59016, 22.95082, 100.00000,
100.00000, 21.77670, 100.00000, 21.40009, 100.00000,
20.11520, 100.00000, 18.83031, 100, 100.00000, 
18.69739, 18.23217, 17.47895, 100.00000,
17.39034, 100.00000, 100.00000,
100.00000, 100.00000, 100])
print(np.size(val_CER_4CNN_4LSTM))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
q = [182.25520, 100.00000, 100.00000, 100.00000, 100.00000, 
100.00000, 100.00000, 100.00000, 100.00000, 100.00000, 
100.00000, 100.00000, 100.00000, 98.18343, 90.38547, 
86.30926, 59.19362, 100.00000, 36.70802, 35.06868, 
34.29331, 28.99867, 100.00000, 28.86575, 27.82454,
27.31502, 25.69783, 24.59016, 22.95082, 100.00000,
100.00000, 21.77670, 100.00000, 21.40009, 100.00000,
20.11520, 100.00000, 18.83031, 100, 100.00000, 
18.69739, 18.23217, 17.47895, 100.00000,
17.39034, 100.00000, 100.00000,
100.00000, 100.00000, 100]

print(np.size(q))
# Out:
# 48

# %%
# Example loss values for 4 different models (replace with actual data)

# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, loss_4LSTM, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, loss_4LSTM2CNN, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, loss_4LSTM4CNN, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, loss_4CNN_4LSTM, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Loss",  fontsize=14)
plt.title("Loss vs. Epochs for LSTM + CNN architectures",  fontsize=14)
Legend = ['baseline', '4 LSTM', '4 LSTM + 2 CNN', '4 LSTM + 4 CNN', '4CNN + 4 LSTM']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# For CER of LSTM + CNN
# Example loss values for 4 different models (replace with actual data)

# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, val_CER_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, val_CER_4LSTM, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, val_CER_4LSTM2CNN, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, val_CER_4LSTM4CNN, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, val_CER_4CNN_4LSTM, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Validation CER",  fontsize=14)
plt.title("Validation CER vs. Epochs for LSTM + CNN architectures",  fontsize=14)
Legend = ['baseline', '4 LSTM', '4 LSTM + 2 CNN', '4 LSTM + 4 CNN', '4CNN + 4 LSTM']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# Bar graphs for val_CER, and test_CER
Legend = ['baseline', '4 LSTM', '4 LSTM + \n 2 CNN', '4 LSTM + \n 4 CNN', '4CNN + \n 4 LSTM'] # X-axis labels
val_CER = [20.69, 19.51, 19.738, 17.32, 17.39]  # Y-axis values (heights of bars)
test_CER = [22.65, 21.007, 19.624, 19.43, 19.40]  

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, val_CER, width=0.8, color='red', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Validation CER (%)", fontsize=14)
plt.title("Validation CER (%) across different LSTM+CNN Architectures", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, test_CER, width=0.8, color='blue', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Test CER (%)", fontsize=14)
plt.title("Test CER (%) across different LSTM+CNN Architectures", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.yticks(fontsize=14)
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# %%
# GRU Data
loss_4GRU = clean([3.66, 3.66, 3.4, 3.37, 3.31, 3.3, 3.22, 3.12, 3.05, 2.95, 
2.8, 2.63, 2.24, 1.89, 1.71, 1.58, 1.42, 1.31, 1.24, 1.18,
1.09, 1.08, 1.04, 0.977, 0.966, 0.946, 0.911, 0.883, 0.861,
0.808, 0.788, 0.778, 0.754, 0.713, 0.703, 0.699, 0.638,
0.667, 0.631, 0.647, 0.612, 0.596, 0.585, 0.588, 0.545,
0.549, 0.53, 0.545, 0.547, 0.537])
print(np.size(loss_4GRU))

val_CER_4GRU = clean([100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
 93.77493, 80.41648, 58.97209, 50.64244, 49.20248, 41.89189,
 39.61010, 36.99601, 34.16039, 100,
 31.23615, 100, 28.77714, 100, 100,
 27.42579, 26.36243, 100, 100, 24.03633,
 100, 23.34958, 22.77359, 100, 100,
 21.51085, 100, 100, 20.80195, 100, 100,
 20.07089, 100, 100, 19.98228, 19.89366,
 19.80505, 19.78290, 100])
print(np.size(val_CER_4GRU))

# GRU + CNN
loss_4GRU4CNN = clean([3.5, 3.5, 3.37, 3.35, 3.23, 3.11, 2.94, 2.93, 2.8, 2.55, 
        2.26, 2.02, 1.81, 1.7, 1.52, 1.45, 1.28, 1.17, 1.15, 1.08,
        1.02, 1.01, 0.932, 0.919, 0.905, 0.832, 0.791, 0.815, 
        0.761, 0.693, 0.718, 0.656, 0.615, 0.628, 0.567, 
        0.594, 0.509, 0.485, 0.478, 0.433, 0.455, 
        0.421, 0.383, 0.378, 0.359, 0.356, 
        0.368, 0.34, 0.351, 0.32])
print(np.size(loss_4GRU4CNN))

val_CER_4GRU4CNN = clean([100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
           95.70226, 86.24280, 78.26761, 70.38103, 48.02835, 38.12583,
           100, 33.96101, 29.50820, 29.22020, 27.97962, 100, 26.53965,
           25.47630, 100, 23.43819, 100, 100, 22.61852, 21.22286,
           21.00133, 20.27027, 100, 19.16261, 100, 100, 18.78600,
           17.98848, 100, 100, 17.67833, 17.12450, 100, 16.34914,
           16.30483, 100, 100, 100, 100, 100])
print(np.size(loss_4GRU4CNN))

# Transformer  + GRU + CNN
loss_2Tf4GRU4CNN = clean([
    3.51, 3.51, 3.38, 3.35, 3.21, 3.16, 3, 2.96, 2.77, 2.54,
    2.23, 1.94, 1.8, 1.65, 1.5, 1.31, 1.32, 1.15, 1.27, 1.1,
    0.998, 1.02, 0.955, 0.899, 0.974, 0.86, 0.853, 0.78,
    0.799, 0.771, 0.725, 0.652, 0.663, 0.637, 0.581,
    0.564, 0.525, 0.526, 0.468, 0.501,
    0.457, 0.425, 0.38, 0.406, 0.361,
    0.371, 0.338, 0.339, 0.324, 0.327
])
print(np.size(loss_2Tf4GRU4CNN))

val_CER_2Tf4GRU4CNN = clean([100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 96.74346,
                        87.94860, 79.41959, 58.13026, 44.06292, 35.20160, 34.24900,
                          33.36287, 100, 27.42579, 26.47319, 100, 26.18520, 25.94151,
                            100, 24.92246, 100, 21.95392, 21.79885, 21.77670, 20.84626,
                              20.15950, 19.71644, 19.27337, 17.61187, 100, 100, 17.50111,
                                16.83651, 100, 16.14976, 15.97253, 15.70669, 15.37439,
                                  100, 15.30793, 100, 15.10855, 100, 100])
print(np.size(val_CER_2Tf4GRU4CNN))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50

# %%
# Loss VS Epoch for GRUs
# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, loss_4LSTM, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, loss_4GRU, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, loss_4LSTM4CNN, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, loss_4GRU4CNN, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Loss",  fontsize=14)
plt.title("Loss vs. Epochs for LSTM/GRU + CNN architectures",  fontsize=14)
Legend = ['baseline', '4 LSTM', '4 GRU', '4 LSTM/GRU + 4 CNN', '4GRU + 4 CNN']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# CER VS Epoch for GRUs
# Example loss values for 4 different models (replace with actual data)

# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, val_CER_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, val_CER_4LSTM, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, val_CER_4GRU, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, val_CER_4LSTM4CNN, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, val_CER_4GRU4CNN, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Validation CER",  fontsize=14)
plt.title("Validation CER vs. Epochs for LSTM/GRU + CNN architectures",  fontsize=14)
Legend = ['baseline', '4 LSTM', '4 GRU', '4 LSTM + 4 CNN', '4GRU + 4 CNN']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# Bar graphs
# Bar graphs for val_CER, and test_CER
Legend = ['baseline', '4 LSTM', '4 GRU', '4 LSTM + \n 4 CNN', '4 GRU + \n 4 CNN'] # X-axis labels
val_CER = [20.69, 19.51, 19.78, 17.32, 16.30]  # Y-axis values (heights of bars)
test_CER = [22.65, 21.007, 19.88, 19.43, 18.11]  

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, val_CER, width=0.8, color='red', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)
# Labels and title

plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Validation CER (%)", fontsize=14)
plt.title("Validation CER (%) across different LSTM/GRU + CNN Architectures", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, test_CER, width=0.8, color='blue', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Test CER (%)", fontsize=14)
plt.title("Test CER (%) across different LSTM/GRU + CNN Architectures", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.yticks(fontsize=14)
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# %%
# Transformer and GPT data
# 4CNN + 2GPT
loss_4CNN2GPT= clean([3.41, 3.41, 3.28, 3.3, 3.29, 3.08, 3.04, 2.96, 2.92, 2.66,
                       2.35, 2.13, 1.99, 1.65, 1.51, 1.4, 1.48, 1.22, 1.15, 1.11,
                         1.02, 1.01, 0.966, 0.95, 0.901, 0.875, 0.825, 0.844, 0.798,
                           0.734, 0.765, 0.664, 0.677, 0.639, 0.626, 0.599, 0.592, 
                           0.546, 0.542, 0.506, 0.455, 0.478, 0.42, 0.417, 0.4, 0.394,
                             0.392, 0.386, 0.376, 0.378])
print(np.size(loss_4CNN2GPT))

val_CER_4CNN2GPT = clean([194.99335, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0,
                           100.0, 100.0, 97.98405, 89.74302, 75.16615, 51.50642,
                             43.46478, 36.99601, 36.99601, 32.49889, 31.08108, 29.97342,
                               29.30882, 28.91006, 28.17900, 25.63137, 25.63137,
                                 25.63137, 24.98892, 23.01728, 23.01728, 23.01728,
                                   23.01728, 22.59637, 22.59637, 21.71024, 21.71024,
                                     21.13425, 20.84626, 19.89366, 19.89366, 19.89366,
                                       19.38414, 19.38414, 19.38414, 19.38414, 18.85246,
                                         18.85246, 18.85246, 18.67523, 18.67523])
print(np.size(val_CER_4CNN2GPT))

# 4CNN + 4GPT
loss_4CNN4GPT = clean([3.44, 3.31, 3.3, 3.33, 3.07, 2.99, 2.94, 2.88, 2.63, 2.33,
                        2.13, 2.03, 1.69, 1.53, 1.44, 1.58, 1.22, 1.14, 1.12, 1.02,
                          1.03, 0.958, 0.934, 0.918, 0.858, 0.811, 0.836,
                            0.788, 0.744, 0.752, 0.666, 0.668, 0.641, 0.621,
                              0.574, 0.585, 0.523, 0.529, 0.49, 0.429,
                                0.45, 0.427, 0.408, 0.381, 0.373, 0.381,
                                  0.379, 0.359, 0.355])
print(np.size(loss_4CNN4GPT))

val_CER_4CNN4GPT = clean([195.72441, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0,
                           100.0, 99.86708, 94.06291, 89.32211, 82.60966, 58.15242, 
                           43.39832, 38.05937, 38.05937, 33.36287, 31.43553, 31.25831,
                             31.12539, 31.12539, 26.05228, 26.05228, 26.05228, 24.34648,
                               24.34648, 24.34648, 24.34648, 24.34648, 22.06469, 21.73239,
                                 21.53301, 21.53301, 21.53301, 20.82410, 20.82410, 19.40629,
                                   19.40629, 19.40629, 19.40629, 18.87461, 18.87461, 18.87461,
                                     18.87461, 18.87461, 18.78600, 18.69739, 18.45370, 18.45370])
print(np.size(loss_4CNN4GPT))

# 4CNN + 4 transformer
loss_4CNN4Tf = clean([3.47, 3.47, 3.41, 3.35, 3.35, 3.27, 3.1, 
                      3.09, 3.03, 2.88, 2.74, 2.34, 2.1, 1.96,
                        1.84, 1.74, 1.57, 1.43, 1.31, 1.23, 1.14,
                          1.21, 1.1, 1.05, 1.02, 0.933, 0.911, 0.944,
                            0.857, 0.872, 0.774, 0.796, 0.726, 0.722, 0.71, 
                            0.631, 0.635, 0.63, 0.566, 0.576, 0.552, 0.504, 0.495, 0.493, 
                            0.462, 0.469, 0.456, 0.414, 0.426, 0.444])
print(np.size(loss_4CNN4Tf))
val_CER_4CNN4Tf = clean([
    100, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 
    100.0, 100.0, 99.68986, 90.51839, 90.45193, 84.35977, 76.05228, 
    60.96589, 42.49003, 38.74612, 35.29021, 31.78999, 29.26451, 
    100.0, 27.35933, 26.31812, 100.0, 25.94151, 24.52370, 
    100.0, 24.28002, 100.0, 22.90651, 22.41914, 
    21.82100, 21.37794, 100.0, 21.26717, 
    20.80195, 100.0, 20.07089, 
    20.04874, 
    19.56137,
    19.25122,
    100.0,
    19.16261,
    100.0,
    19.00753,
    18.85246,
    100, 100
])
print(np.size(val_CER_4CNN4Tf))


# 4CNN + 2 transformer
loss_4CNN2Tf = clean([
    3.47, 3.47, 3.4, 3.32, 3.22, 3.16, 2.99, 2.98, 2.86, 2.64,
    2.41, 2.19, 2.04, 1.91, 1.72, 1.63, 1.43, 1.3, 1.26, 1.19,
    1.16, 1.11, 1.08, 1.06, 1.01, 0.938, 0.906, 0.986, 0.882,
    0.867, 0.779, 0.797, 0.746, 0.751, 0.705, 0.649, 0.635,
    0.624, 0.563, 0.572, 0.536, 0.503, 0.5, 0.486, 0.472,
    0.47, 0.461, 0.423, 0.433, 0.445
])
print(np.size(loss_4CNN2Tf))
val_CER_4CNN2Tf = clean([100, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 
    97.20869, 90.38547, 88.25875, 87.85999, 79.08728, 70.58041, 61.80771,
    42.55649, 35.46743, 34.29331, 33.20780, 100.0, 29.48604, 100.0,
    28.24546, 27.66947, 26.03013, 100.0, 100.0, 25.71998,
    23.99203, 23.68188, 22.66283, 100.0, 100,
    20.97918, 100, 20.35888, 100, 20.22596, 19.58352, 19.56137, 100, 19.16261, 100, 
    18.78600, 18.18786, 100, 100, 100, 100])
print(np.size(val_CER_4CNN2Tf))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
# Example loss values for 4 different models (replace with actual data)

# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, loss_4CNN2GPT, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, loss_4CNN4GPT, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, loss_4CNN2Tf, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, loss_4CNN4Tf, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Loss",  fontsize=14)
plt.title("Loss vs. Epochs for Transformer + CNN architectures",  fontsize=14)
Legend = ['baseline', '4 CNN +\n 2GPT', '4 CNN +\n 4 GPT', '4 CNN +\n 2 Transformer', '4CNN +\n 4 Transformer']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# For CER of CNN + transformers
# Example loss values for 4 different models (replace with actual data)

# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, val_CER_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, val_CER_4CNN2GPT, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, val_CER_4CNN4GPT, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, val_CER_4CNN2Tf, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, val_CER_4CNN4Tf, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Validation CER",  fontsize=14)
plt.title("Validation CER vs. Epochs for Transformer + CNN architectures",  fontsize=14)
Legend = ['baseline', '4 CNN +\n 2 GPT', '4 CNN +\n 4 GPT', '4 CNN +\n 2 Transformer', '4CNN +\n 4 Transformer']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# Bar graphs for val_CER, and test_CER
val_CER = [20.69, 20.38, 20.38, 18.18, 18.85]  # Y-axis values (heights of bars)
test_CER = [22.65, 24.35, 24.87]  
Legend = ['baseline', '4 CNN +\n 2 GPT', '4 CNN +\n 4 GPT', '4 CNN +\n 2 Transformer', '4CNN +\n 4 Transformer']
# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, val_CER, width=0.8, color='red', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Validation CER (%)", fontsize=14)
plt.title("Validation CER (%) across different Transformer+CNN Architectures", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(['baseline','4CNN +\n 2 Transformer','4CNN +\n 4 Transformer'], test_CER, width=0.8, color='blue', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Test CER (%)", fontsize=14)
plt.title("Test CER (%) across different Transformer+CNN Architectures", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.yticks(fontsize=14)
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# %%
# 2 Transformer + 4 GRU + 4 CNN

loss_2Tf4GRU4CNN = clean([3.51, 3.51, 3.38, 3.35, 3.21, 3.16, 3.0, 2.96, 2.77,
                     2.54, 2.23, 1.94, 1.8, 1.65, 1.5, 1.31, 1.32, 1.15, 
                     1.27, 1.1, 0.998, 1.02, 0.955, 0.899, 0.974, 0.86,
                       0.853, 0.78, 0.799, 0.771, 0.725, 0.652, 0.663, 
                       0.637, 0.581, 0.564, 0.525, 0.526, 0.468, 0.501, 
                       0.457, 0.425, 0.38, 0.406, 0.361, 0.371, 0.338, 
                       0.339, 0.324, 0.327])
print(np.size(loss_2Tf4GRU4CNN))
val_CER_2Tf4GRU4CNN = clean([100, 100.0, 100.0, 100.0, 100.0, 100.0,
                              100.0, 100.0, 100.0, 100.0, 96.74346, 87.94860,
                              79.41959, 58.13026, 44.06292, 35.20160, 34.24900,
                              33.36287, 100.0, 27.42579, 26.47319, 100.0, 
                              26.18520, 25.94151, 100.0, 24.92246, 100.0, 
                              21.95392, 21.79885, 21.77670, 20.84626, 
                              20.15950, 19.71644, 19.27337, 17.61187, 100.0,
                              100.0, 17.50111, 16.83651, 100.0, 16.14976, 15.97253,
                              15.70669, 15.37439, 100.0, 15.30793, 100.0, 15.10855, 100.0, 100.0])
print(np.size(val_CER_2Tf4GRU4CNN))

# 2 Transformer + 4 BiLSTM + 4 CNN (Premkumar)
loss_2Tf4LSTM4CNN = clean([
    3.46, 3.46, 3.33, 3.28, 3.19, 3.13, 2.97, 2.93, 2.81, 2.58,
    2.35, 2.05, 1.9, 1.82, 1.65, 1.59, 1.47, 1.42, 1.38, 1.33,
    1.31, 1.22, 1.16, 1.24, 1.21, 1.44, 1.34, 1.18, 1.15, 1.05,
    0.996, 0.963, 0.933, 0.875, 0.867, 0.841, 0.792, 0.789,
    0.763, 0.745, 0.695, 0.703, 0.681, 0.649, 0.646,
    0.636, 0.61, 0.628, 0.609, 0.6
])
print(np.size(loss_2Tf4LSTM4CNN))
val_CER_2Tf4LSTM4CNN = clean([
    100, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0,
    99.26894, 95.45857, 93.24324, 67.12450, 60.74435, 54.60789, 45.85733,
    40.09747, 100.0, 36.04342, 35.09083, 34.02747, 31.96721, 29.68542,
    100.0, 100.0, 100.0, 100.0, 100.0, 29.17590, 27.73593,
    27.02703, 26.47319, 24.43509, 23.99203, 23.70403, 22.97297,
    100.0, 100.0, 22.88436, 21.77670, 21.68808, 21.28932,
    100.0, 20.31458, 20.11520, 100.0, 20.00443, 
    19.87151, 19.73859, 100])
print(np.size(val_CER_2Tf4LSTM4CNN))
# Out:
# 50
# 50
# 50
# 50

# %%
# Plots comparing the best models

# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, loss_4LSTM4CNN, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, loss_2Tf4LSTM4CNN, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, loss_4GRU4CNN, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, loss_2Tf4GRU4CNN, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Loss",  fontsize=14)
plt.title("Loss vs. Epochs for Transformer + LSTM/GRU + CNN Architecture",  fontsize=14)
Legend = ['baseline','4 LSTM + 4 CNN','2 Transformer + 4 LSTM + 4 CNN','4 GRU + 4 CNN','2 Transformer + 4 GRU + 4 CNN']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# Plot Loss vs. Epoch for each model
plt.figure(figsize=(10, 6))
plt.plot(epochs, val_CER_baseline, marker='o', linestyle='-', label="Model 1", color='b', linewidth=2)
plt.plot(epochs, val_CER_4LSTM4CNN, marker='s', linestyle='--', label="Model 2", color='r', linewidth=2)
plt.plot(epochs, val_CER_2Tf4LSTM4CNN, marker='^', linestyle='-.', label="Model 3", color='g', linewidth=2)
plt.plot(epochs, val_CER_4GRU4CNN, marker='d', linestyle=':', label="Model 4", color='m', linewidth=2)
plt.plot(epochs, val_CER_2Tf4GRU4CNN, marker='d', linestyle=':', label="Model 4", color='c', linewidth=2)

# Labels, title, and legend
plt.xlabel("Epochs",  fontsize=14)
plt.ylabel("Validation CER",  fontsize=14)
plt.title("Validation CER vs. Epochs for Transformer + LSTM/GRU + CNN Architecture",  fontsize=14)
Legend = ['baseline','4 LSTM + 4 CNN','2 Transformer + 4 LSTM + 4 CNN','4 GRU + 4 CNN','2 Transformer + 4 GRU + 4 CNN']
plt.legend(Legend,  fontsize=14)
plt.grid(True, linestyle="--", alpha=1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()

# %%
# Bar graphs for val_CER, and test_CER
Legend = ['baseline','4 LSTM + \n 4 CNN','2 Transformer + \n 4 LSTM + \n 4 CNN','4 GRU + \n 4 CNN','2 Transformer + \n 4 GRU + \n 4 CNN']
val_CER = [20.69, 17.32, 19.74, 16.30, 15.11]  # Y-axis values (heights of bars)
test_CER = [22.65, 19.43, 19.94, 18.11, 17.61]  

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, val_CER, width=0.8, color='red', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Validation CER (%)", fontsize=14)
plt.title("Validation CER (%) across different Transformer + LSTM/GRU + CNN Architecture", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, test_CER, width=0.8, color='blue', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("Architectures", fontsize=14)
plt.ylabel("Test CER (%)", fontsize=14)
plt.title("Test CER (%) across different Transformer + LSTM/GRU + CNN Architecture", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(np.linspace(0, 25, 11))
plt.yticks(fontsize=14)
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# %%
# Different number of electrode channel study 
# Bar graphs for val_CER, and test_CER
Legend = ['baseline','4 Electrode \n Channel','8 Electrode \n Channel','16 Electrode \n Channel']
val_CER = [20.69, 28.86, 22.55, 15.11]  # Y-axis values (heights of bars)
test_CER = [22.65, 32.05, 25.99, 17.61]  

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, val_CER, width=0.8, color='red', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("No. of Electrode Channels", fontsize=14)
plt.ylabel("Validation CER (%)", fontsize=14)
plt.title("Val CER (%) for 2Trnsf+4GRU+4CNN with different no. of electrode channels", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.linspace(0, 30, 13))
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()

# Create bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(Legend, test_CER, width=0.8, color='blue', edgecolor='black', linewidth=1.5, alpha=0.7)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Labels and title
plt.xlabel("No. of Electrode Channels", fontsize=14)
plt.ylabel("Test CER (%)", fontsize=14)
plt.title("Test CER (%) for 2Trnsf+4GRU+4CNN with different no. of electrode channels", fontsize=14)
plt.xticks(rotation=0)
plt.xticks(fontsize=14)
plt.yticks(np.linspace(0, 32.5, 14))
plt.yticks(fontsize=14)
plt.grid(True, linestyle="--", alpha=0.8)
# Show the plot
plt.show()
